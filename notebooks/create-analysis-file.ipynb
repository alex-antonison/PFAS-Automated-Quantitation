# %%
import pandas as pd

# %%
df = (pd.read_parquet("../data/processed/build-data-products/blank_filtered_evaluated_qc_no_recovery.parquet")
        .dropna(subset=["evaluate_recovery_ratio_flag"])
        .loc[:,["batch_number", "evaluate_recovery_ratio_flag"]]
        .groupby(["batch_number", "evaluate_recovery_ratio_flag"])
        .size()
        .reset_index(name='counts')
)

df
# Out:
#     batch_number evaluate_recovery_ratio_flag  counts
# 0            1.0                         FAIL     104
# 1            1.0                         PASS       8
# 2            2.0                         FAIL      90
# 3            2.0                         PASS       6
# 4            3.0                         FAIL      96
# 5            3.0                         PASS      12
# 6            4.0                         FAIL      85
# 7            4.0                         PASS      15
# 8            5.0                         FAIL      93
# 9            5.0                         PASS      12
# 10           6.0                         FAIL     105
# 11           6.0                         PASS      19
# 12           7.0                         FAIL      76
# 13           7.0                         PASS       2
# 14           8.0                         FAIL     107
# 15           8.0                         PASS      16
# ...

# %%
df.groupby(["batch_number", "evaluate_recovery_ratio_flag"])["batch_number"].transform('count').reset_index()

# %%
        # .groupby(["batch_number", "evaluate_recovery_ratio_flag"])["batch_number"]
        # .transform('count')
        # .reset_index(keep=False)
